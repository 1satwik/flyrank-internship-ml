# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/1satwik/flyrank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# # 1. My lane (or freestyle) and why
#
# **Lane:** Search Ranking & Discoverability
#
# I chose the Search Ranking & Discoverability lane because I want to understand which page features are associated with better search performance. From the Week 1 notebooks, I observed that content length alone did not explain performance, suggesting that other factors may be more important. This lane will help identify patterns that can support better decisions for improving page visibility.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# # 2. The question: decision, action, cost of a wrong call
#
# **Decision:** Determine which page characteristics are associated with better search ranking and visibility.
#
# **Who acts on it?** SEO specialists, content writers, and website owners.
#
# **Action:** Prioritize improving the factors that are most strongly associated with better search performance instead of focusing only on content length.
#
# **Cost of a wrong recommendation:** If the recommendations are incorrect, time and resources may be spent optimizing the wrong aspects of a page, leading to lower visibility, fewer visitors, and missed opportunities.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data
#
# The starter dataset contains **30,000 pages**. The **median word count is 2,877 words**. The median CTR varies by trend direction: **stable pages have the highest median CTR (0.17)**, while **up (0.09)** and **down (0.08)** pages are lower, and **flat** and **new** pages have a median CTR of **0.00**. These observations suggest that page performance depends on factors beyond content length, making this a useful lane for further investigation.

# %%
# 2–3 real numbers supporting my lane

print("Total pages:", len(df))
print("Median word count:", df["word_count"].median())

print("\nMedian CTR by trend direction:")
print(df.groupby("trend_direction")["ctr"].median())
# Out:
# Total pages: 30000
# Median word count: 2877.0
#
# Median CTR by trend direction:
# trend_direction
# down      0.08
# flat      0.00
# new       0.00
# stable    0.17
# up        0.09
# Name: ctr, dtype: float64

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# This work can identify relationships between page features and search performance that may help guide SEO decisions.
#
# It cannot prove that a feature directly causes better rankings or predict Google's ranking algorithm. The findings should be used as decision support rather than causal proof.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
